# %%
import requests
from bs4 import BeautifulSoup
from retry import retry
import urllib
import time
import numpy as np
import pandas as pd
from datetime import date

from sqlalchemy import create_engine
from sqlalchemy import text

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
from joblib import dump
from joblib import load

# %%
# 複数ページの情報をまとめて取得
data_samples = []

# スクレイピングするページ数
max_page = 100
# SUUMOを桜山のみ指定して検索して出力した画面のurl(ページ数フォーマットが必要)
base_url = 'https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=050&bs=040&ra=023&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&ek=323016210&rn=3230'

# リクエストがうまく行かないパターンを回避するためのやり直し
@retry(tries=3, delay=10, backoff=2)
def load_page(url):
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    return soup

# 処理時間を測りたい
start = time.time()
times = []


for page in range(1, max_page + 1):
    # ページネーション用のクエリパラメータを追加
    url = f'{base_url}&page={page}'
    soup = load_page(url)
    before = time.time()
    # 物件情報リストを指定
    mother = soup.find_all(class_='cassetteitem')
        
    # 物件ごとの処理
    for child in mother:

        # 建物情報
        data_home = []
        # カテゴリ
        data_home.append(child.find(class_='ui-pct ui-pct--util1').text)
        # 建物名
        data_home.append(child.find(class_='cassetteitem_content-title').text)
        # 住所
        data_home.append(child.find(class_='cassetteitem_detail-col1').text)
        # 最寄り駅のアクセス
        children = child.find(class_='cassetteitem_detail-col2')
        for id,grandchild in enumerate(children.find_all(class_='cassetteitem_detail-text')):
            data_home.append(grandchild.text)
        # 築年数と階数
        children = child.find(class_='cassetteitem_detail-col3')
        for grandchild in children.find_all('div'):
            data_home.append(grandchild.text)

        # 部屋情報
        rooms = child.find(class_='cassetteitem_other')
        for room in rooms.find_all(class_='js-cassette_link'):
            data_room = []
            
            # 部屋情報が入っている表を探索
            for id_, grandchild in enumerate(room.find_all('td')):
                # 階
                if id_ == 2:
                    data_room.append(grandchild.text.strip())
                # 家賃と管理費
                elif id_ == 3:
                    data_room.append(grandchild.find(class_='cassetteitem_other-emphasis ui-text--bold').text)
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--administration').text)
                # 敷金と礼金
                elif id_ == 4:
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--deposit').text)
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--gratuity').text)
                # 間取りと面積
                elif id_ == 5:
                    data_room.append(grandchild.find(class_='cassetteitem_madori').text)
                    data_room.append(grandchild.find(class_='cassetteitem_menseki').text)
                # url
                elif id_ == 8:
                    get_url = grandchild.find(class_='js-cassette_link_href cassetteitem_other-linktext').get('href')
                    abs_url = urllib.parse.urljoin(url,get_url)
                    data_room.append(abs_url)
            # 物件情報と部屋情報をくっつける
            data_sample = data_home + data_room
            data_samples.append(data_sample)
    
    # 1アクセスごとに1秒休む
    time.sleep(1)
    
    # 進捗確認
    # このページの作業時間を表示
    after = time.time()
    running_time = after - before
    times.append(running_time)
    print(f'{page}ページ目：{running_time}秒')
    # 取得した件数
    print(f'総取得件数：{len(data_samples)}')
    # 作業進捗
    complete_ratio = round(page/max_page*100,3)
    print(f'完了：{complete_ratio}%')
    # 作業の残り時間目安を表示
    running_mean = np.mean(times)
    running_required_time = running_mean * (max_page - page)
    hour = int(running_required_time/3600)
    minute = int((running_required_time%3600)/60)
    second = int(running_required_time%60)
    print(f'残り時間：{hour}時間{minute}分{second}秒\n')

# 処理時間を測りたい
finish = time.time()
running_all = finish - start
print('総経過時間：',running_all)
# Out:
# 1ページ目：1.1774530410766602秒
# 総取得件数：117
# 完了：1.0%
# 残り時間：0時間1分56秒
#
# 2ページ目：1.1913528442382812秒
# 総取得件数：222
# 完了：2.0%
# 残り時間：0時間1分56秒
#
# 3ページ目：1.1082723140716553秒
# 総取得件数：288
# 完了：3.0%
# 残り時間：0時間1分52秒
#
# 4ページ目：1.1119129657745361秒
# 総取得件数：356
# 完了：4.0%
# 残り時間：0時間1分50秒
#
# 5ページ目：1.0951380729675293秒
# 総取得件数：415
# 完了：5.0%
# 残り時間：0時間1分47秒
#
# 6ページ目：1.1030068397521973秒
# 総取得件数：473
# 完了：6.0%
# 残り時間：0時間1分46秒
#
# 7ページ目：1.1250560283660889秒
# 総取得件数：548
# 完了：7.0%
# 残り時間：0時間1分45秒
#
# 8ページ目：1.1157119274139404秒
# 総取得件数：625
# 完了：8.0%
# 残り時間：0時間1分43秒
#
# 9ページ目：1.117715835571289秒
# 総取得件数：703
# 完了：9.0%
# 残り時間：0時間1分42秒
#
# 10ページ目：1.1086511611938477秒
# 総取得件数：771
# 完了：10.0%
# 残り時間：0時間1分41秒
#
# 11ページ目：1.0942409038543701秒
# 総取得件数：825
# 完了：11.0%
# 残り時間：0時間1分39秒
#
# 12ページ目：1.0985112190246582秒
# 総取得件数：887
# 完了：12.0%
# 残り時間：0時間1分38秒
#
# 13ページ目：1.0912330150604248秒
# 総取得件数：942
# 完了：13.0%
# 残り時間：0時間1分37秒
#
# 14ページ目：1.0996880531311035秒
# 総取得件数：1001
# 完了：14.0%
# 残り時間：0時間1分36秒
#
# 15ページ目：1.0853021144866943秒
# 総取得件数：1047
# 完了：15.0%
# 残り時間：0時間1分34秒
#
# 16ページ目：1.146272897720337秒
# 総取得件数：1163
# 完了：16.0%
# 残り時間：0時間1分33秒
#
# 17ページ目：1.1015071868896484秒
# 総取得件数：1225
# 完了：17.0%
# 残り時間：0時間1分32秒
#
# 18ページ目：1.0912089347839355秒
# 総取得件数：1278
# 完了：18.0%
# 残り時間：0時間1分31秒
#
# 19ページ目：1.1042249202728271秒
# 総取得件数：1342
# 完了：19.0%
# 残り時間：0時間1分30秒
#
# 20ページ目：1.1335821151733398秒
# 総取得件数：1417
# 完了：20.0%
# 残り時間：0時間1分29秒
#
# 21ページ目：1.147244930267334秒
# 総取得件数：1529
# 完了：21.0%
# 残り時間：0時間1分28秒
#
# 22ページ目：1.1136360168457031秒
# 総取得件数：1607
# 完了：22.0%
# 残り時間：0時間1分27秒
#
# 23ページ目：1.0930259227752686秒
# 総取得件数：1662
# 完了：23.0%
# 残り時間：0時間1分25秒
#
# 24ページ目：1.0837531089782715秒
# 総取得件数：1703
# 完了：24.0%
# 残り時間：0時間1分24秒
#
# 25ページ目：1.088284969329834秒
# 総取得件数：1753
# 完了：25.0%
# 残り時間：0時間1分23秒
#
# 26ページ目：1.0887396335601807秒
# 総取得件数：1801
# 完了：26.0%
# 残り時間：0時間1分22秒
#
# 27ページ目：1.0941901206970215秒
# 総取得件数：1859
# 完了：27.0%
# 残り時間：0時間1分21秒
#
# 28ページ目：1.1004838943481445秒
# 総取得件数：1921
# 完了：28.0%
# 残り時間：0時間1分19秒
#
# 29ページ目：1.1071569919586182秒
# 総取得件数：1991
# 完了：29.0%
# 残り時間：0時間1分18秒
#
# 30ページ目：1.0841097831726074秒
# 総取得件数：2034
# 完了：30.0%
# 残り時間：0時間1分17秒
#
# 31ページ目：1.066288948059082秒
# 総取得件数：2067
# 完了：31.0%
# 残り時間：0時間1分16秒
#
# 32ページ目：1.013718843460083秒
# 総取得件数：2067
# 完了：32.0%
# 残り時間：0時間1分15秒
#
# 33ページ目：1.0130548477172852秒
# 総取得件数：2067
# 完了：33.0%
# 残り時間：0時間1分13秒
#
# 34ページ目：1.0137460231781006秒
# 総取得件数：2067
# 完了：34.0%
# 残り時間：0時間1分12秒
#
# 35ページ目：1.0122087001800537秒
# 総取得件数：2067
# 完了：35.0%
# 残り時間：0時間1分11秒
#
# 36ページ目：1.0164909362792969秒
# 総取得件数：2067
# 完了：36.0%
# 残り時間：0時間1分10秒
#
# 37ページ目：1.0146429538726807秒
# 総取得件数：2067
# 完了：37.0%
# 残り時間：0時間1分8秒
#
# 38ページ目：1.0166850090026855秒
# 総取得件数：2067
# 完了：38.0%
# 残り時間：0時間1分7秒
#
# 39ページ目：1.0152819156646729秒
# 総取得件数：2067
# 完了：39.0%
# 残り時間：0時間1分6秒
#
# 40ページ目：1.0162320137023926秒
# 総取得件数：2067
# 完了：40.0%
# 残り時間：0時間1分5秒
#
# 41ページ目：1.016629934310913秒
# 総取得件数：2067
# 完了：41.0%
# 残り時間：0時間1分4秒
#
# 42ページ目：1.0157020092010498秒
# 総取得件数：2067
# 完了：42.0%
# 残り時間：0時間1分2秒
#
# 43ページ目：1.0130228996276855秒
# 総取得件数：2067
# 完了：43.0%
# 残り時間：0時間1分1秒
#
# 44ページ目：1.0127918720245361秒
# 総取得件数：2067
# 完了：44.0%
# 残り時間：0時間1分0秒
#
# 45ページ目：1.0177879333496094秒
# 総取得件数：2067
# 完了：45.0%
# 残り時間：0時間0分59秒
#
# 46ページ目：1.0165181159973145秒
# 総取得件数：2067
# 完了：46.0%
# 残り時間：0時間0分58秒
#
# 47ページ目：1.014458179473877秒
# 総取得件数：2067
# 完了：47.0%
# 残り時間：0時間0分57秒
#
# 48ページ目：1.0150573253631592秒
# 総取得件数：2067
# 完了：48.0%
# 残り時間：0時間0分55秒
#
# 49ページ目：1.0121588706970215秒
# 総取得件数：2067
# 完了：49.0%
# 残り時間：0時間0分54秒
#
# 50ページ目：1.0155761241912842秒
# 総取得件数：2067
# 完了：50.0%
# 残り時間：0時間0分53秒
#
# 51ページ目：1.0155389308929443秒
# 総取得件数：2067
# 完了：51.0%
# 残り時間：0時間0分52秒
#
# 52ページ目：1.017488956451416秒
# 総取得件数：2067
# 完了：52.0%
# 残り時間：0時間0分51秒
#
# 53ページ目：1.0155832767486572秒
# 総取得件数：2067
# 完了：53.0%
# 残り時間：0時間0分50秒
#
# 54ページ目：1.015286922454834秒
# 総取得件数：2067
# 完了：54.0%
# 残り時間：0時間0分49秒
#
# 55ページ目：1.0125949382781982秒
# 総取得件数：2067
# 完了：55.0%
# 残り時間：0時間0分48秒
#
# 56ページ目：1.0168719291687012秒
# 総取得件数：2067
# 完了：56.0%
# 残り時間：0時間0分46秒
#
# 57ページ目：1.01344895362854秒
# 総取得件数：2067
# 完了：57.0%
# 残り時間：0時間0分45秒
#
# 58ページ目：1.0135447978973389秒
# 総取得件数：2067
# 完了：58.0%
# 残り時間：0時間0分44秒
#
# 59ページ目：1.016465187072754秒
# 総取得件数：2067
# 完了：59.0%
# 残り時間：0時間0分43秒
#
# 60ページ目：1.0130798816680908秒
# 総取得件数：2067
# 完了：60.0%
# 残り時間：0時間0分42秒
#
# 61ページ目：1.0197031497955322秒
# 総取得件数：2067
# 完了：61.0%
# 残り時間：0時間0分41秒
#
# 62ページ目：1.0180189609527588秒
# 総取得件数：2067
# 完了：62.0%
# 残り時間：0時間0分40秒
#
# 63ページ目：1.0121541023254395秒
# 総取得件数：2067
# 完了：63.0%
# 残り時間：0時間0分39秒
#
# 64ページ目：1.0156230926513672秒
# 総取得件数：2067
# 完了：64.0%
# 残り時間：0時間0分38秒
#
# 65ページ目：1.017014980316162秒
# 総取得件数：2067
# 完了：65.0%
# 残り時間：0時間0分37秒
#
# 66ページ目：1.0125761032104492秒
# 総取得件数：2067
# 完了：66.0%
# 残り時間：0時間0分36秒
#
# 67ページ目：1.0155978202819824秒
# 総取得件数：2067
# 完了：67.0%
# 残り時間：0時間0分34秒
#
# 68ページ目：1.0140023231506348秒
# 総取得件数：2067
# 完了：68.0%
# 残り時間：0時間0分33秒
#
# 69ページ目：1.0155339241027832秒
# 総取得件数：2067
# 完了：69.0%
# 残り時間：0時間0分32秒
#
# 70ページ目：1.016740322113037秒
# 総取得件数：2067
# 完了：70.0%
# 残り時間：0時間0分31秒
#
# 71ページ目：1.0162360668182373秒
# 総取得件数：2067
# 完了：71.0%
# 残り時間：0時間0分30秒
#
# 72ページ目：1.0171618461608887秒
# 総取得件数：2067
# 完了：72.0%
# 残り時間：0時間0分29秒
#
# 73ページ目：1.0133538246154785秒
# 総取得件数：2067
# 完了：73.0%
# 残り時間：0時間0分28秒
#
# 74ページ目：1.0119569301605225秒
# 総取得件数：2067
# 完了：74.0%
# 残り時間：0時間0分27秒
#
# 75ページ目：1.0122871398925781秒
# 総取得件数：2067
# 完了：75.0%
# 残り時間：0時間0分26秒
#
# 76ページ目：1.0116908550262451秒
# 総取得件数：2067
# 完了：76.0%
# 残り時間：0時間0分25秒
#
# 77ページ目：1.0127370357513428秒
# 総取得件数：2067
# 完了：77.0%
# 残り時間：0時間0分24秒
#
# 78ページ目：1.0180208683013916秒
# 総取得件数：2067
# 完了：78.0%
# 残り時間：0時間0分23秒
#
# 79ページ目：1.0146582126617432秒
# 総取得件数：2067
# 完了：79.0%
# 残り時間：0時間0分22秒
#
# 80ページ目：1.013118028640747秒
# 総取得件数：2067
# 完了：80.0%
# 残り時間：0時間0分21秒
#
# 81ページ目：1.016937017440796秒
# 総取得件数：2067
# 完了：81.0%
# 残り時間：0時間0分19秒
#
# 82ページ目：1.0119388103485107秒
# 総取得件数：2067
# 完了：82.0%
# 残り時間：0時間0分18秒
#
# 83ページ目：1.015643835067749秒
# 総取得件数：2067
# 完了：83.0%
# 残り時間：0時間0分17秒
#
# 84ページ目：1.0169751644134521秒
# 総取得件数：2067
# 完了：84.0%
# 残り時間：0時間0分16秒
#
# 85ページ目：1.0149738788604736秒
# 総取得件数：2067
# 完了：85.0%
# 残り時間：0時間0分15秒
#
# 86ページ目：1.0149331092834473秒
# 総取得件数：2067
# 完了：86.0%
# 残り時間：0時間0分14秒
#
# 87ページ目：1.0125491619110107秒
# 総取得件数：2067
# 完了：87.0%
# 残り時間：0時間0分13秒
#
# 88ページ目：1.012420892715454秒
# 総取得件数：2067
# 完了：88.0%
# 残り時間：0時間0分12秒
#
# 89ページ目：1.0148060321807861秒
# 総取得件数：2067
# 完了：89.0%
# 残り時間：0時間0分11秒
#
# 90ページ目：1.0127122402191162秒
# 総取得件数：2067
# 完了：90.0%
# 残り時間：0時間0分10秒
#
# 91ページ目：1.0152623653411865秒
# 総取得件数：2067
# 完了：91.0%
# 残り時間：0時間0分9秒
#
# 92ページ目：1.0151901245117188秒
# 総取得件数：2067
# 完了：92.0%
# 残り時間：0時間0分8秒
#
# 93ページ目：1.0114078521728516秒
# 総取得件数：2067
# 完了：93.0%
# 残り時間：0時間0分7秒
#
# 94ページ目：1.0141239166259766秒
# 総取得件数：2067
# 完了：94.0%
# 残り時間：0時間0分6秒
#
# 95ページ目：1.0136888027191162秒
# 総取得件数：2067
# 完了：95.0%
# 残り時間：0時間0分5秒
#
# 96ページ目：1.0142459869384766秒
# 総取得件数：2067
# 完了：96.0%
# 残り時間：0時間0分4秒
#
# 97ページ目：1.0171170234680176秒
# 総取得件数：2067
# 完了：97.0%
# 残り時間：0時間0分3秒
#
# 98ページ目：1.0115931034088135秒
# 総取得件数：2067
# 完了：98.0%
# 残り時間：0時間0分2秒
#
# 99ページ目：1.0122811794281006秒
# 総取得件数：2067
# 完了：99.0%
# 残り時間：0時間0分1秒
#
# 100ページ目：1.013901948928833秒
# 総取得件数：2067
# 完了：100.0%
# 残り時間：0時間0分0秒
#
# 総経過時間： 159.23613214492798

# %%
# data_samplesをDataFrameに変換
columns = ['property_type', 'building_name', 'address', 'access_1', 'access_2', 'access_3',
    'age', 'building_floors', 'room_floor', 'rent', 'management_fee',
    'deposit', 'gratuity', 'layout', 'area', 'url']
df = pd.DataFrame(data_samples, columns=columns)

# 現在の日付を掲載日として入力
current_date = date.today()
df['posting_date'] = current_date

# %%
# 重複行を削除
df_unique = df.drop_duplicates()

# df_unique

# %%
# 前処理

# 共益費management_feeと敷金(deposit)と礼金(gratuity)が「-」の場合は0とする
df_unique['management_fee'] = df_unique['management_fee'].replace('-', '0円')
df_unique['deposit'] = df_unique['deposit'].replace('-', '0万円')
df_unique['gratuity'] = df_unique['gratuity'].replace('-', '0万円')

# 金額関連の列を数値に変換する関数
def yen_to_float(yen_str):
    return float(yen_str.replace('万円', '')) * 10000

# rent, management_fee, deposit, gratuity を数値に変換
df_unique['rent'] = df_unique['rent'].apply(yen_to_float)
df_unique['management_fee'] = df_unique['management_fee'].str.replace('円', '').astype(float)
df_unique['deposit'] = df_unique['deposit'].apply(yen_to_float)
df_unique['gratuity'] = df_unique['gratuity'].apply(yen_to_float)

# 面積を数値に変換
df_unique['area'] = df_unique['area'].str.replace('m2', '').astype(float)

# 実質負担額を計算（rent + management_fee + (deposit + gratuity) / 48）
df_unique['actual_cost'] = df_unique['rent'] + df_unique['management_fee'] + (df_unique['deposit'] + df_unique['gratuity']) / 48
# Out:
# /Users/gr39my/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df_unique.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2057 entries, 0 to 2066
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   property_type    2057 non-null   object
#  1   building_name    2057 non-null   object
#  2   address          2057 non-null   object
#  3   access_1         2057 non-null   object
#  4   access_2         2057 non-null   object
#  5   access_3         2057 non-null   object
#  6   age              2057 non-null   object
#  7   building_floors  2057 non-null   object
#  8   room_floor       2057 non-null   object
#  9   rent             2057 non-null   float64
#  10  management_fee   2057 non-null   float64
#  11  deposit          2057 non-null   float64
#  12  gratuity         2057 non-null   float64
#  13  layout           2057 non-null   object
#  14  area             2057 non-null   float64
#  15  url              2057 non-null   object
#  16  posting_date     2057 non-null   object
#  17  actual_cost      2057 non-null   float64
# dtypes: float64(6), object(12)
# memory usage: 305.3+ KB

# %% [markdown]
# # データの保存

# %%
df_unique.to_csv('scraped_data.csv')

# %% [markdown]
# # データベース関連の処理

# %%
# CSVファイルを読み込む
df = pd.read_csv('scraped_data.csv', index_col=0)

# %%
# SQLiteデータベースファイルのパス
database_path = 'rent_app.sqlite3'

# SQLiteデータベースへの接続情報
engine = create_engine(f'sqlite:///{database_path}')

# データベーステーブル 'rental_properties' を読み込み
db_df = pd.read_sql_table('rental_properties', engine)

# %%
df.head(2)
# Out:
#   property_type       building_name         address        access_1  \
# 0        賃貸アパート  地下鉄桜通線 桜山駅 2階建 築8年  愛知県名古屋市瑞穂区駒場町４  地下鉄桜通線/桜山駅 歩3分
# 1        賃貸アパート  地下鉄桜通線 桜山駅 2階建 築8年  愛知県名古屋市瑞穂区駒場町４  地下鉄桜通線/桜山駅 歩3分
#
#             access_2          access_3  age building_floors room_floor  \
# 0  地下鉄桜通線/瑞穂区役所駅 歩9分  地下鉄鶴舞線/御器所駅 歩20分  築8年             2階建         1階
# 1  地下鉄桜通線/瑞穂区役所駅 歩9分  地下鉄鶴舞線/御器所駅 歩20分  築8年             2階建         1階
#
#       rent  management_fee  deposit  gratuity layout   area  \
# 0  53500.0          4000.0      0.0       0.0     1K  20.13
# 1  53500.0          4000.0      0.0       0.0    1SK  20.13
#
#                                                  url posting_date  actual_cost
# 0  https://suumo.jp/chintai/jnc_000062206827/?bc=...   2024-02-25      57500.0
# 1  https://suumo.jp/chintai/jnc_000088370773/?bc=...   2024-02-25      57500.0

# %%
db_df.head(2)
# Out:
# Empty DataFrame
# Columns: [id, property_type, building_name, address, access_1, access_2, access_3, age, building_floors, room_floor, rent, management_fee, deposit, gratuity, layout, area, url, posting_date, removed_date, actual_cost, predict_cost]
# Index: []
#
# [0 rows x 21 columns]

# %%
# 新規レコードの挿入
## スクレイピングしたデータ（df）にあって、データベース（db_df）にないレコードを特定
new_records = df.merge(db_df, on=['url'], how='left', indicator=True).loc[lambda x : x['_merge']=='left_only']

## 不要なカラムを削除
new_records = new_records.drop(columns=['_merge'])

## 新規レコードに掲載日を設定
#new_records['posting_date'] = current_date

# カラム名を修正するためのrename操作
new_records.rename(columns={
    'property_type_x': 'property_type',
    'building_name_x': 'building_name',
    'address_x': 'address',
    'access_1_x': 'access_1',
    'access_2_x': 'access_2',
    'access_3_x': 'access_3',
    'age_x': 'age',
    'building_floors_x': 'building_floors',
    'room_floor_x': 'room_floor',
    'rent_x': 'rent',
    'management_fee_x': 'management_fee',
    'deposit_x': 'deposit',
    'gratuity_x': 'gratuity',
    'layout_x': 'layout',
    'area_x': 'area',
    'url_x': 'url',
    'posting_date_x': 'posting_date',
    'actual_cost_x': 'actual_cost'
}, inplace=True)

# 例: 不要なカラムを削除し、必要なカラムのみを選択
cleaned_df = new_records[['property_type', 'building_name', 'address', 'access_1', 'access_2', 'access_3', 'age', 'building_floors', 'room_floor', 'rent', 'management_fee', 'deposit', 'gratuity', 'layout', 'area', 'url', 'posting_date', 'actual_cost']].copy()

## 新規レコードをデータベースに挿入
cleaned_df.to_sql('rental_properties', engine, if_exists='append', index=False)

# %%
cleaned_df.head(2)
# Out:
#   property_type       building_name         address        access_1  \
# 0        賃貸アパート  地下鉄桜通線 桜山駅 2階建 築8年  愛知県名古屋市瑞穂区駒場町４  地下鉄桜通線/桜山駅 歩3分
# 1        賃貸アパート  地下鉄桜通線 桜山駅 2階建 築8年  愛知県名古屋市瑞穂区駒場町４  地下鉄桜通線/桜山駅 歩3分
#
#             access_2          access_3  age building_floors room_floor  \
# 0  地下鉄桜通線/瑞穂区役所駅 歩9分  地下鉄鶴舞線/御器所駅 歩20分  築8年             2階建         1階
# 1  地下鉄桜通線/瑞穂区役所駅 歩9分  地下鉄鶴舞線/御器所駅 歩20分  築8年             2階建         1階
#
#       rent  management_fee  deposit  gratuity layout   area  \
# 0  53500.0          4000.0      0.0       0.0     1K  20.13
# 1  53500.0          4000.0      0.0       0.0    1SK  20.13
#
#                                                  url posting_date  actual_cost
# 0  https://suumo.jp/chintai/jnc_000062206827/?bc=...   2024-02-25      57500.0
# 1  https://suumo.jp/chintai/jnc_000088370773/?bc=...   2024-02-25      57500.0

# %%
# 削除されたレコードの特定と更新
## データベースにあって、スクレイピングしたデータにないレコードを特定
removed_records = db_df.merge(df, on=['url'], how='left', indicator=True).loc[lambda x : x['_merge'] == 'left_only']

# removed_dateがNULL（つまり、未設定）のレコードに対してのみ更新を行う
for index, row in removed_records.iterrows():
    # removed_dateが未設定かどうかを確認するためのクエリ
    check_query = text("SELECT removed_date FROM rental_properties WHERE url = :url AND removed_date IS NULL")
    result = engine.execute(check_query, url=row['url']).fetchone()
    
    # removed_dateが未設定の場合のみ、removed_dateを更新する
    if result:
        update_query = text("UPDATE rental_properties SET removed_date = :current_date WHERE url = :url AND removed_date IS NULL")
        engine.execute(update_query, current_date=current_date, url=row['url'])

# %% [markdown]
# # 機械学習モデルによる予測値の入力

# %%
# # dbを読み込み
# df = pd.read_sql_table('rental_properties', engine)
# ml_df = pd.read_sql_table('rental_properties', engine)

# %% [markdown]
# ## 前処理

# %%
# # 桜山駅からの最短時間を取得する関数
# def get_min_time_to_sakurayama(access_str):
#     if pd.isnull(access_str):
#         return np.nan
#     times = [int(s.split('歩')[1].replace('分', '')) for s in access_str.split('/') if '桜山駅' in s]
#     if times:
#         return min(times)
#     else:
#         return np.nan

# # access_1, access_2, access_3から桜山駅までの最短時間を計算
# ml_df['min_time_to_sakurayama'] = ml_df[['access_1', 'access_2', 'access_3']].apply(
#     lambda x: min(
#         filter(pd.notnull, [get_min_time_to_sakurayama(x['access_1']), get_min_time_to_sakurayama(x['access_2']), get_min_time_to_sakurayama(x['access_3'])]),
#         default=np.nan
#     ),
#     axis=1
# )

# %%
# # '築新'または'新'を'0'年として扱うための処理を追加
# ml_df['age'] = ml_df['age'].str.replace('築新', '0').str.replace('新', '0').str.replace('築', '').str.replace('年', '')


# # 空の値を0に置き換え
# ml_df['age'] = ml_df['age'].replace('', '0')

# # 整数型に変換
# ml_df['age'] = ml_df['age'].astype(int)

# # 建物の階数と部屋の階についても同様に処理
# ml_df['building_floors'] = ml_df['building_floors'].str.extract('(\d+)')[0].fillna('0').astype(int)
# ml_df['room_floor'] = ml_df['room_floor'].str.extract('(\d+)')[0].fillna('0').astype(int)

# %%
# # 不要なカラムを削除
# drop_cols = ['posting_date', 'removed_date', 'building_name', 'access_1', 'access_2', 'access_3', 'posting_date']
# ml_df.drop(drop_cols, axis=1, inplace=True)

# %%
# ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          0 non-null      object
#  1   property_type               768 non-null    object
#  2   address                     768 non-null    object
#  3   age                         768 non-null    int64
#  4   building_floors             768 non-null    int64
#  5   room_floor                  768 non-null    int64
#  6   rent                        768 non-null    float64
#  7   management_fee              768 non-null    float64
#  8   deposit                     768 non-null    float64
#  9   gratuity                    768 non-null    float64
#  10  layout                      768 non-null    object
#  11  area                        768 non-null    float64
#  12  url                         768 non-null    object
#  13  actual_cost                 768 non-null    float64
#  14  want_rent                   0 non-null      object
#  15  want_rent_if_5000_cheaper   0 non-null      object
#  16  want_rent_if_10000_cheaper  0 non-null      object
#  17  predict_cost                0 non-null      float64
#  18  min_time_to_sakurayama      768 non-null    int64
# dtypes: float64(7), int64(4), object(8)
# memory usage: 114.1+ KB

# %%
# # エンコーディングするカラム
# categorical_cols = ['property_type', 'address', 'layout']

# # One-hotエンコーディング
# ml_df = pd.get_dummies(ml_df, columns=categorical_cols)

# %% [markdown]
# ## モデルでの予測

# %%
# ml_df.columns = ml_df.columns.astype(str)

# # 特徴量とターゲット変数に分割
# X_new = ml_df.drop(['id','url', 'predict_cost'], axis=1)  # ,'predict_cost'# actual_cost以外のすべてのカラムを特徴量として使用
# y_new = ml_df['actual_cost']  # actual_costをターゲット変数として使用

# %%
# # 保存されたモデルをロードする
# random_forest_model = load('random_forest_model.joblib')
# gradient_boosting_model = load('gradient_boosting_model.joblib')

# # ランダムフォレストモデルで予測する
# predictions_rf = random_forest_model.predict(X_new)

# # グラディエントブースティングモデルで予測する
# predictions_gb = gradient_boosting_model.predict(X_new)

# # 予測結果をml_dfに追加
# ml_df['predict_cost'] = (predictions_rf + predictions_gb) / 2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/57/b_s78qts1fqf11dkv9hjb3f80000gn/T/ipykernel_2331/2628321543.py in <module>
#       4
#       5 # ランダムフォレストモデルで予測する
# ----> 6 predictions_rf = random_forest_model.predict(X_new)
#       7
#       8 # グラディエントブースティングモデルで予測する
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     979         check_is_fitted(self)
#     980         # Check data
# --> 981         X = self._validate_X_predict(X)
#     982
#     983         # Assign chunk of trees to jobs
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _validate_X_predict(self, X)
#     600         Validate X whenever one tries to predict, apply, predict_proba."""
#     601         check_is_fitted(self)
# --> 602         X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     603         if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     604             raise ValueError("No support for np.int64 index based sparse matrices")
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     546             validated.
#     547         """
# --> 548         self._check_feature_names(X, reset=reset)
#     549
#     550         if y is None and self._get_tags()["requires_y"]:
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/sklearn/base.py in _check_feature_names(self, X, reset)
#     479                 )
#     480
# --> 481             raise ValueError(message)
#     482
#     483     def _validate_data(
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - want_rent
# - want_rent_if_10000_cheaper
# - want_rent_if_5000_cheaper
# Feature names seen at fit time, yet now missing:
# - address_愛知県名古屋市北区喜惣治１
# - address_愛知県名古屋市南区桜台１
# - address_愛知県名古屋市昭和区丸屋町１
# - address_愛知県名古屋市昭和区丸屋町２
# - address_愛知県名古屋市昭和区丸屋町３
# - ...

# %%
# from sqlalchemy.sql import text

# # データベースにデータを格納する（例: 'rental_properties' テーブルを更新）
# for index, row in ml_df.iterrows():
#     # ここでは、URLを一意の識別子と仮定して、そのURLに対応するレコードを更新します。
#     update_query = text("""
#     UPDATE rental_properties
#     SET actual_cost = :actual_cost, predict_cost = :predict_cost
#     WHERE url = :url
#     """)
#     engine.execute(update_query, {'actual_cost': row['actual_cost'], 'predict_cost': row['predict_cost'], 'url': row['url']})
