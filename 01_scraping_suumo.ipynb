# %%
import requests
from bs4 import BeautifulSoup
from retry import retry
import urllib
import time
import numpy as np
import pandas as pd
from datetime import date

from sqlalchemy import create_engine
from sqlalchemy import text

# %%
# 複数ページの情報をまとめて取得
data_samples = []

# スクレイピングするページ数
max_page = 100
# SUUMOを桜山のみ指定して検索して出力した画面のurl(ページ数フォーマットが必要)
base_url = 'https://suumo.jp/jj/chintai/ichiran/FR301FC001/?ar=050&bs=040&ra=023&cb=0.0&ct=9999999&et=9999999&cn=9999999&mb=0&mt=9999999&shkr1=03&shkr2=03&shkr3=03&shkr4=03&fw2=&ek=323016210&rn=3230'

# リクエストがうまく行かないパターンを回避するためのやり直し
@retry(tries=3, delay=10, backoff=2)
def load_page(url):
    html = requests.get(url)
    soup = BeautifulSoup(html.content, 'html.parser')
    return soup

# 処理時間を測りたい
start = time.time()
times = []


for page in range(1, max_page + 1):
    # ページネーション用のクエリパラメータを追加
    url = f'{base_url}&page={page}'
    soup = load_page(url)
    before = time.time()
    # 物件情報リストを指定
    mother = soup.find_all(class_='cassetteitem')
        
    # 物件ごとの処理
    for child in mother:

        # 建物情報
        data_home = []
        # カテゴリ
        data_home.append(child.find(class_='ui-pct ui-pct--util1').text)
        # 建物名
        data_home.append(child.find(class_='cassetteitem_content-title').text)
        # 住所
        data_home.append(child.find(class_='cassetteitem_detail-col1').text)
        # 最寄り駅のアクセス
        children = child.find(class_='cassetteitem_detail-col2')
        for id,grandchild in enumerate(children.find_all(class_='cassetteitem_detail-text')):
            data_home.append(grandchild.text)
        # 築年数と階数
        children = child.find(class_='cassetteitem_detail-col3')
        for grandchild in children.find_all('div'):
            data_home.append(grandchild.text)

        # 部屋情報
        rooms = child.find(class_='cassetteitem_other')
        for room in rooms.find_all(class_='js-cassette_link'):
            data_room = []
            
            # 部屋情報が入っている表を探索
            for id_, grandchild in enumerate(room.find_all('td')):
                # 階
                if id_ == 2:
                    data_room.append(grandchild.text.strip())
                # 家賃と管理費
                elif id_ == 3:
                    data_room.append(grandchild.find(class_='cassetteitem_other-emphasis ui-text--bold').text)
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--administration').text)
                # 敷金と礼金
                elif id_ == 4:
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--deposit').text)
                    data_room.append(grandchild.find(class_='cassetteitem_price cassetteitem_price--gratuity').text)
                # 間取りと面積
                elif id_ == 5:
                    data_room.append(grandchild.find(class_='cassetteitem_madori').text)
                    data_room.append(grandchild.find(class_='cassetteitem_menseki').text)
                # url
                elif id_ == 8:
                    get_url = grandchild.find(class_='js-cassette_link_href cassetteitem_other-linktext').get('href')
                    abs_url = urllib.parse.urljoin(url,get_url)
                    data_room.append(abs_url)
            # 物件情報と部屋情報をくっつける
            data_sample = data_home + data_room
            data_samples.append(data_sample)
    
    # 1アクセスごとに1秒休む
    time.sleep(1)
    
    # 進捗確認
    # このページの作業時間を表示
    after = time.time()
    running_time = after - before
    times.append(running_time)
    print(f'{page}ページ目：{running_time}秒')
    # 取得した件数
    print(f'総取得件数：{len(data_samples)}')
    # 作業進捗
    complete_ratio = round(page/max_page*100,3)
    print(f'完了：{complete_ratio}%')
    # 作業の残り時間目安を表示
    running_mean = np.mean(times)
    running_required_time = running_mean * (max_page - page)
    hour = int(running_required_time/3600)
    minute = int((running_required_time%3600)/60)
    second = int(running_required_time%60)
    print(f'残り時間：{hour}時間{minute}分{second}秒\n')

# 処理時間を測りたい
finish = time.time()
running_all = finish - start
print('総経過時間：',running_all)
# Out:
# 1ページ目：1.1103999614715576秒
# 総取得件数：68
# 完了：1.0%
# 残り時間：0時間1分49秒
#
# 2ページ目：1.2136387825012207秒
# 総取得件数：184
# 完了：2.0%
# 残り時間：0時間1分53秒
#
# 3ページ目：1.1342899799346924秒
# 総取得件数：255
# 完了：3.0%
# 残り時間：0時間1分51秒
#
# 4ページ目：1.1552250385284424秒
# 総取得件数：324
# 完了：4.0%
# 残り時間：0時間1分50秒
#
# 5ページ目：1.103426218032837秒
# 総取得件数：381
# 完了：5.0%
# 残り時間：0時間1分48秒
#
# 6ページ目：1.1460950374603271秒
# 総取得件数：443
# 完了：6.0%
# 残り時間：0時間1分47秒
#
# 7ページ目：1.133180856704712秒
# 総取得件数：534
# 完了：7.0%
# 残り時間：0時間1分46秒
#
# 8ページ目：1.111072063446045秒
# 総取得件数：596
# 完了：8.0%
# 残り時間：0時間1分44秒
#
# 9ページ目：1.1303939819335938秒
# 総取得件数：675
# 完了：9.0%
# 残り時間：0時間1分43秒
#
# 10ページ目：1.162782907485962秒
# 総取得件数：788
# 完了：10.0%
# 残り時間：0時間1分42秒
#
# 11ページ目：1.0901567935943604秒
# 総取得件数：838
# 完了：11.0%
# 残り時間：0時間1分41秒
#
# 12ページ目：1.108285903930664秒
# 総取得件数：906
# 完了：12.0%
# 残り時間：0時間1分39秒
#
# 13ページ目：1.1071081161499023秒
# 総取得件数：976
# 完了：13.0%
# 残り時間：0時間1分38秒
#
# 14ページ目：1.1043860912322998秒
# 総取得件数：1037
# 完了：14.0%
# 残り時間：0時間1分37秒
#
# 15ページ目：1.0956878662109375秒
# 総取得件数：1090
# 完了：15.0%
# 残り時間：0時間1分35秒
#
# 16ページ目：1.097682237625122秒
# 総取得件数：1145
# 完了：16.0%
# 残り時間：0時間1分34秒
#
# 17ページ目：1.1475629806518555秒
# 総取得件数：1249
# 完了：17.0%
# 残り時間：0時間1分33秒
#
# 18ページ目：1.1217882633209229秒
# 総取得件数：1312
# 完了：18.0%
# 残り時間：0時間1分32秒
#
# 19ページ目：1.2090468406677246秒
# 総取得件数：1374
# 完了：19.0%
# 残り時間：0時間1分31秒
#
# 20ページ目：1.0854427814483643秒
# 総取得件数：1419
# 完了：20.0%
# 残り時間：0時間1分30秒
#
# 21ページ目：1.1192209720611572秒
# 総取得件数：1492
# 完了：21.0%
# 残り時間：0時間1分29秒
#
# 22ページ目：1.1250677108764648秒
# 総取得件数：1579
# 完了：22.0%
# 残り時間：0時間1分27秒
#
# 23ページ目：1.1140360832214355秒
# 総取得件数：1652
# 完了：23.0%
# 残り時間：0時間1分26秒
#
# 24ページ目：1.0786781311035156秒
# 総取得件数：1692
# 完了：24.0%
# 残り時間：0時間1分25秒
#
# 25ページ目：1.0802459716796875秒
# 総取得件数：1732
# 完了：25.0%
# 残り時間：0時間1分24秒
#
# 26ページ目：1.0902152061462402秒
# 総取得件数：1783
# 完了：26.0%
# 残り時間：0時間1分23秒
#
# 27ページ目：1.1023569107055664秒
# 総取得件数：1848
# 完了：27.0%
# 残り時間：0時間1分21秒
#
# 28ページ目：1.0942530632019043秒
# 総取得件数：1902
# 完了：28.0%
# 残り時間：0時間1分20秒
#
# 29ページ目：1.097311019897461秒
# 総取得件数：1957
# 完了：29.0%
# 残り時間：0時間1分19秒
#
# 30ページ目：1.1209149360656738秒
# 総取得件数：2031
# 完了：30.0%
# 残り時間：0時間1分18秒
#
# 31ページ目：1.0866410732269287秒
# 総取得件数：2079
# 完了：31.0%
# 残り時間：0時間1分17秒
#
# 32ページ目：1.0443549156188965秒
# 総取得件数：2097
# 完了：32.0%
# 残り時間：0時間1分15秒
#
# 33ページ目：1.0120482444763184秒
# 総取得件数：2097
# 完了：33.0%
# 残り時間：0時間1分14秒
#
# 34ページ目：1.0301768779754639秒
# 総取得件数：2097
# 完了：34.0%
# 残り時間：0時間1分13秒
#
# 35ページ目：1.0150790214538574秒
# 総取得件数：2097
# 完了：35.0%
# 残り時間：0時間1分12秒
#
# 36ページ目：1.0142872333526611秒
# 総取得件数：2097
# 完了：36.0%
# 残り時間：0時間1分10秒
#
# 37ページ目：1.0150160789489746秒
# 総取得件数：2097
# 完了：37.0%
# 残り時間：0時間1分9秒
#
# 38ページ目：1.0120279788970947秒
# 総取得件数：2097
# 完了：38.0%
# 残り時間：0時間1分8秒
#
# 39ページ目：1.015423059463501秒
# 総取得件数：2097
# 完了：39.0%
# 残り時間：0時間1分6秒
#
# 40ページ目：1.0124049186706543秒
# 総取得件数：2097
# 完了：40.0%
# 残り時間：0時間1分5秒
#
# 41ページ目：1.0150439739227295秒
# 総取得件数：2097
# 完了：41.0%
# 残り時間：0時間1分4秒
#
# 42ページ目：1.0113682746887207秒
# 総取得件数：2097
# 完了：42.0%
# 残り時間：0時間1分3秒
#
# 43ページ目：1.0159242153167725秒
# 総取得件数：2097
# 完了：43.0%
# 残り時間：0時間1分2秒
#
# 44ページ目：1.0152649879455566秒
# 総取得件数：2097
# 完了：44.0%
# 残り時間：0時間1分0秒
#
# 45ページ目：1.0137560367584229秒
# 総取得件数：2097
# 完了：45.0%
# 残り時間：0時間0分59秒
#
# 46ページ目：1.017953872680664秒
# 総取得件数：2097
# 完了：46.0%
# 残り時間：0時間0分58秒
#
# 47ページ目：1.015674114227295秒
# 総取得件数：2097
# 完了：47.0%
# 残り時間：0時間0分57秒
#
# 48ページ目：1.0154600143432617秒
# 総取得件数：2097
# 完了：48.0%
# 残り時間：0時間0分56秒
#
# 49ページ目：1.0153629779815674秒
# 総取得件数：2097
# 完了：49.0%
# 残り時間：0時間0分55秒
#
# 50ページ目：1.010970115661621秒
# 総取得件数：2097
# 完了：50.0%
# 残り時間：0時間0分53秒
#
# 51ページ目：1.0700452327728271秒
# 総取得件数：2097
# 完了：51.0%
# 残り時間：0時間0分52秒
#
# 52ページ目：1.0157480239868164秒
# 総取得件数：2097
# 完了：52.0%
# 残り時間：0時間0分51秒
#
# 53ページ目：1.0125699043273926秒
# 総取得件数：2097
# 完了：53.0%
# 残り時間：0時間0分50秒
#
# 54ページ目：1.015913963317871秒
# 総取得件数：2097
# 完了：54.0%
# 残り時間：0時間0分49秒
#
# 55ページ目：1.0103511810302734秒
# 総取得件数：2097
# 完了：55.0%
# 残り時間：0時間0分48秒
#
# 56ページ目：1.0147480964660645秒
# 総取得件数：2097
# 完了：56.0%
# 残り時間：0時間0分47秒
#
# 57ページ目：1.0163581371307373秒
# 総取得件数：2097
# 完了：57.0%
# 残り時間：0時間0分46秒
#
# 58ページ目：1.0103869438171387秒
# 総取得件数：2097
# 完了：58.0%
# 残り時間：0時間0分45秒
#
# 59ページ目：1.0143969058990479秒
# 総取得件数：2097
# 完了：59.0%
# 残り時間：0時間0分43秒
#
# 60ページ目：1.0112111568450928秒
# 総取得件数：2097
# 完了：60.0%
# 残り時間：0時間0分42秒
#
# 61ページ目：1.0114359855651855秒
# 総取得件数：2097
# 完了：61.0%
# 残り時間：0時間0分41秒
#
# 62ページ目：1.0129868984222412秒
# 総取得件数：2097
# 完了：62.0%
# 残り時間：0時間0分40秒
#
# 63ページ目：1.011857271194458秒
# 総取得件数：2097
# 完了：63.0%
# 残り時間：0時間0分39秒
#
# 64ページ目：1.0207879543304443秒
# 総取得件数：2097
# 完了：64.0%
# 残り時間：0時間0分38秒
#
# 65ページ目：1.0165910720825195秒
# 総取得件数：2097
# 完了：65.0%
# 残り時間：0時間0分37秒
#
# 66ページ目：1.0110132694244385秒
# 総取得件数：2097
# 完了：66.0%
# 残り時間：0時間0分36秒
#
# 67ページ目：1.011997938156128秒
# 総取得件数：2097
# 完了：67.0%
# 残り時間：0時間0分35秒
#
# 68ページ目：1.0132362842559814秒
# 総取得件数：2097
# 完了：68.0%
# 残り時間：0時間0分34秒
#
# 69ページ目：1.0132911205291748秒
# 総取得件数：2097
# 完了：69.0%
# 残り時間：0時間0分32秒
#
# 70ページ目：1.013719081878662秒
# 総取得件数：2097
# 完了：70.0%
# 残り時間：0時間0分31秒
#
# 71ページ目：1.0122778415679932秒
# 総取得件数：2097
# 完了：71.0%
# 残り時間：0時間0分30秒
#
# 72ページ目：1.0128059387207031秒
# 総取得件数：2097
# 完了：72.0%
# 残り時間：0時間0分29秒
#
# 73ページ目：1.0151729583740234秒
# 総取得件数：2097
# 完了：73.0%
# 残り時間：0時間0分28秒
#
# 74ページ目：1.0150787830352783秒
# 総取得件数：2097
# 完了：74.0%
# 残り時間：0時間0分27秒
#
# 75ページ目：1.0171101093292236秒
# 総取得件数：2097
# 完了：75.0%
# 残り時間：0時間0分26秒
#
# 76ページ目：1.0163860321044922秒
# 総取得件数：2097
# 完了：76.0%
# 残り時間：0時間0分25秒
#
# 77ページ目：1.0134551525115967秒
# 総取得件数：2097
# 完了：77.0%
# 残り時間：0時間0分24秒
#
# 78ページ目：1.0136597156524658秒
# 総取得件数：2097
# 完了：78.0%
# 残り時間：0時間0分23秒
#
# 79ページ目：1.0160541534423828秒
# 総取得件数：2097
# 完了：79.0%
# 残り時間：0時間0分22秒
#
# 80ページ目：1.0159337520599365秒
# 総取得件数：2097
# 完了：80.0%
# 残り時間：0時間0分21秒
#
# 81ページ目：1.0169050693511963秒
# 総取得件数：2097
# 完了：81.0%
# 残り時間：0時間0分20秒
#
# 82ページ目：1.0118436813354492秒
# 総取得件数：2097
# 完了：82.0%
# 残り時間：0時間0分18秒
#
# 83ページ目：1.0119948387145996秒
# 総取得件数：2097
# 完了：83.0%
# 残り時間：0時間0分17秒
#
# 84ページ目：1.015627145767212秒
# 総取得件数：2097
# 完了：84.0%
# 残り時間：0時間0分16秒
#
# 85ページ目：1.0112390518188477秒
# 総取得件数：2097
# 完了：85.0%
# 残り時間：0時間0分15秒
#
# 86ページ目：1.0142910480499268秒
# 総取得件数：2097
# 完了：86.0%
# 残り時間：0時間0分14秒
#
# 87ページ目：1.0137438774108887秒
# 総取得件数：2097
# 完了：87.0%
# 残り時間：0時間0分13秒
#
# 88ページ目：1.0149331092834473秒
# 総取得件数：2097
# 完了：88.0%
# 残り時間：0時間0分12秒
#
# 89ページ目：1.0142149925231934秒
# 総取得件数：2097
# 完了：89.0%
# 残り時間：0時間0分11秒
#
# 90ページ目：1.0152349472045898秒
# 総取得件数：2097
# 完了：90.0%
# 残り時間：0時間0分10秒
#
# 91ページ目：1.0161828994750977秒
# 総取得件数：2097
# 完了：91.0%
# 残り時間：0時間0分9秒
#
# 92ページ目：1.0123257637023926秒
# 総取得件数：2097
# 完了：92.0%
# 残り時間：0時間0分8秒
#
# 93ページ目：1.0141918659210205秒
# 総取得件数：2097
# 完了：93.0%
# 残り時間：0時間0分7秒
#
# 94ページ目：1.0159590244293213秒
# 総取得件数：2097
# 完了：94.0%
# 残り時間：0時間0分6秒
#
# 95ページ目：1.016185998916626秒
# 総取得件数：2097
# 完了：95.0%
# 残り時間：0時間0分5秒
#
# 96ページ目：1.0155208110809326秒
# 総取得件数：2097
# 完了：96.0%
# 残り時間：0時間0分4秒
#
# 97ページ目：1.0158450603485107秒
# 総取得件数：2097
# 完了：97.0%
# 残り時間：0時間0分3秒
#
# 98ページ目：1.0144340991973877秒
# 総取得件数：2097
# 完了：98.0%
# 残り時間：0時間0分2秒
#
# 99ページ目：1.0135679244995117秒
# 総取得件数：2097
# 完了：99.0%
# 残り時間：0時間0分1秒
#
# 100ページ目：1.0154080390930176秒
# 総取得件数：2097
# 完了：100.0%
# 残り時間：0時間0分0秒
#
# 総経過時間： 162.87477016448975

# %%
# data_samplesをDataFrameに変換
columns = ['property_type', 'building_name', 'address', 'access_1', 'access_2', 'access_3',
    'age', 'building_floors', 'room_floor', 'rent', 'management_fee',
    'deposit', 'gratuity', 'layout', 'area', 'url']
df = pd.DataFrame(data_samples, columns=columns)

# 現在の日付を掲載日として入力
current_date = date.today()
df['posting_date'] = current_date

# %%
df
# Out:
#      property_type          building_name         address           access_1  \
# 0           賃貸アパート     地下鉄桜通線 桜山駅 2階建 築8年  愛知県名古屋市昭和区滝子通４     地下鉄桜通線/桜山駅 歩7分
# 1          賃貸マンション                 フロイデ桜山  愛知県名古屋市昭和区菊園町４    地下鉄桜通線/桜山駅 歩11分
# 2          賃貸マンション                アヴニール桜山  愛知県名古屋市昭和区桜山町５     地下鉄桜通線/桜山駅 歩2分
# 3          賃貸マンション                  Ｅｚサイト  愛知県名古屋市昭和区大和町１     地下鉄桜通線/桜山駅 歩5分
# 4           賃貸アパート     地下鉄桜通線 桜山駅 2階建 築8年  愛知県名古屋市瑞穂区駒場町４     地下鉄桜通線/桜山駅 歩3分
# ...            ...                    ...             ...                ...
# 2092       賃貸マンション               メルヴェーユ高辻   愛知県名古屋市昭和区白金３   名鉄名古屋本線/金山駅 歩20分
# 2093       賃貸マンション   地下鉄鶴舞線 御器所駅 2階建 築51年  愛知県名古屋市昭和区長戸町１   地下鉄鶴舞線/御器所駅 歩12分
# 2094        賃貸一戸建て               長戸町4丁目貸家  愛知県名古屋市昭和区長戸町４    地下鉄鶴舞線/川名駅 歩10分
# 2092   4.4万円          3500円       -        -     1K  23.04m2
# 2093  6.05万円          3300円       -        -  ワンルーム  39.66m2
# 2094    12万円              -    12万円     12万円   3LDK  69.99m2
# 2095   3.5万円          2000円   3.5万円        -     1K  21.53m2
# 2096    18万円              -    54万円     18万円    3DK  86.49m2
#
#                                                     url posting_date
# 0     https://suumo.jp/chintai/jnc_000088214111/?bc=...   2024-02-19
# 1     https://suumo.jp/chintai/jnc_000088573366/?bc=...   2024-02-19
# 2     https://suumo.jp/chintai/jnc_000088573368/?bc=...   2024-02-19
# 3     https://suumo.jp/chintai/jnc_000076484377/?bc=...   2024-02-19
# 4     https://suumo.jp/chintai/jnc_000088370773/?bc=...   2024-02-19
# ...                                                 ...          ...
# 2092  https://suumo.jp/chintai/jnc_000083895772/?bc=...   2024-02-19
# 2093  https://suumo.jp/chintai/jnc_000088547081/?bc=...   2024-02-19
# 2094  https://suumo.jp/chintai/jnc_000085151800/?bc=...   2024-02-19
# 2095  https://suumo.jp/chintai/jnc_000088444956/?bc=...   2024-02-19
# 2096  https://suumo.jp/chintai/jnc_000087328342/?bc=...   2024-02-19
#
# [2082 rows x 17 columns]

# %% [markdown]
# # データの保存

# %%
df_unique.to_csv('scraped_data.csv')

# %% [markdown]
# # データベース関連の処理

# %%
# CSVファイルを読み込む
df = pd.read_csv('scraped_data.csv', index_col=0)

# %%
import configparser

config = configparser.ConfigParser()
config.read('config.ini')

db_user = config['database']['user']
db_password = config['database']['password']
db_host = config['database']['host']
db_name = config['database']['name']

# %%
# PostgreSQLデータベースへの接続情報
engine = create_engine(f'postgresql://{db_user}:{db_password}@{db_host}/{db_name}')

# dbを読み込み
db_df = pd.read_sql_table('rental_properties', engine)

# %%
# 新規レコードの挿入
## スクレイピングしたデータ（df）にあって、データベース（db_df）にないレコードを特定
new_records = df.merge(db_df, on=['url'], how='left', indicator=True).loc[lambda x : x['_merge']=='left_only']

## 不要なカラムを削除
new_records = new_records.drop(columns=['_merge'])

## 新規レコードに掲載日を設定
new_records['posting_date'] = current_date

# カラム名を修正するためのrename操作
new_records.rename(columns={
    'property_type_x': 'property_type',
    'building_name_x': 'building_name',
    'address_x': 'address',
    'access_1_x': 'access_1',
    'access_2_x': 'access_2',
    'access_3_x': 'access_3',
    'age_x': 'age',
    'building_floors_x': 'building_floors',
    'room_floor_x': 'room_floor',
    'rent_x': 'rent',
    'management_fee_x': 'management_fee',
    'deposit_x': 'deposit',
    'gratuity_x': 'gratuity',
    'layout_x': 'layout',
    'area_x': 'area',
    'url_x': 'url',
    'posting_date_x': 'posting_date'
}, inplace=True)

# 例: 不要なカラムを削除し、必要なカラムのみを選択
cleaned_df = new_records[['building_name', 'address', 'access_1', 'access_2', 'access_3', 'age', 'building_floors', 'room_floor', 'rent', 'management_fee', 'deposit', 'gratuity', 'layout', 'area', 'url', 'posting_date']].copy()

## 新規レコードをデータベースに挿入
cleaned_df.to_sql('rental_properties', engine, if_exists='append', index=False)

# %%
# 削除されたレコードの特定と更新
## データベースにあって、スクレイピングしたデータにないレコードを特定
removed_records = db_df.merge(df, on=['url'], how='left', indicator=True).loc[lambda x : x['_merge'] == 'left_only']

## removed_dateを更新
for index, row in removed_records.iterrows():
    update_query = text("UPDATE rental_properties SET removed_date = :current_date WHERE url = :url")
    engine.execute(update_query, current_date=current_date, url=row['url'])
